# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvanjo/Data-Science/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4+5
# Out:
# 9

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
print(df)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.desccribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-13-1754336376.py in <cell line: 0>()
# ----> 1 df.desccribe()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'desccribe'

# %%
# prompt: give me a code to display ,whose salaries are more than 100000

df_filtered = df[df['salary'] > 100000]
df_filtered

# %%
# prompt: now filter whose salaries are more than 200000,if none say no

df_filtered_200k = df[df['salary'] > 200000]
if df_filtered_200k.empty:
  print("No salaries are more than 200000")
else:
df_filtered_200k

# %%
# prompt: who has the lowest salary in the above data

# Sort the dataframe by salary in ascending order
df_sorted = df.sort_values(by='salary', ascending=True)

# Get the row with the lowest salary
lowest_salary_employee = df_sorted.iloc[0]

print("Employee with the lowest salary:")
lowest_salary_employee

# %%
# prompt: make the above code more easy and simple

print("Employee with the lowest salary:")
df.loc[df['salary'].idxmin()]

# %%
df['salary'].mean()

# %%
# prompt: apply median for salary

df['salary'].median()

# %%
df[['salary','service']].var()
# Out:
# salary     8.005313e+08
# service    1.473740e+02
# dtype: float64

# %%
df[['salary','service']].std()
# Out:
# salary     28293.661022
# service       12.139768
# dtype: float64

# %%
df['salary'].skew()
# Out:
# np.float64(0.45210256755588096)

# %%
df['salary'].kurt()
# Out:
# np.float64(-0.4017126758820546)

# %%
# prompt: check if there are null values in my data set

df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
# prompt: check the above for each cell of date set ,print false if no null

import numpy as np

# Check for null values in each cell and print False if no null
for index, row in df.iterrows():
  for col_name in df.columns:
    if pd.isnull(row[col_name]):
      print(f"Null value found at row {index}, column {col_name}")
    else:
      False

# %%
df.iloc[0:10,0:4]
# Out:
#         rank discipline  phd  service
# 0       Prof          B   56       49
# 1       Prof          A   12        6
# 2       Prof          A   23       20
# 3       Prof          A   40       31
# 4       Prof          B   20       18
# 5       Prof          A   20       20
# 6  AssocProf          A   20       17
# 7       Prof          A   18       18
# 8       Prof          A   29       19
# 9       Prof          A   51       51

# %%
pd.set_option('display.max_columns',None)

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
plt.xlabel('SATSCORES')
plt.ylabel('FREQUENCY')
plt.title('Histogram of SAT scores')
# Out:
# Text(0.5, 1.0, 'Histogram of SAT scores')

# %%
sns.histplot(df1['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
# prompt: change the color of above histogram to red

plt.hist(df1['SAT'], color='red')
plt.xlabel('SATSCORES')
plt.ylabel('FREQUENCY')
plt.title('Histogram of SAT scores')
# Out:
# Text(0.5, 1.0, 'Histogram of SAT scores')

# %%
# prompt: each interval with different color

n, bins, patches = plt.hist(df1['SAT'], bins=10)

for i in range(len(patches)):
  if i % 2 == 0:  # Even intervals (starting from 0)
    patches[i].set_facecolor('red')
  else:  # Odd intervals
    patches[i].set_facecolor('blue')

plt.xlabel('SATSCORES')
plt.ylabel('FREQUENCY')
plt.title('Histogram of SAT scores with alternating colors')
plt.show()

# %%
# prompt: make the same for seaborn histogram

sns.histplot(df1['SAT'], color='blue')
plt.xlabel('SATSCORES')
plt.ylabel('FREQUENCY')
plt.title('Seaborn Histogram of SAT scores')
plt.show()

# %%
# prompt: each interval with different color

# Plotting the histogram again, this time directly with matplotlib for more control over colors
n, bins, patches = plt.hist(df1['SAT'], bins=10)

# Assign different colors to intervals
for i in range(len(patches)):
  # Example: color the first 3 intervals blue, the next 4 red, and the rest green
  if i < 3:
    patches[i].set_facecolor('blue')
  elif i < 7:
    patches[i].set_facecolor('red')
  else:
    patches[i].set_facecolor('green')


plt.xlabel('SATSCORES')
plt.ylabel('FREQUENCY')
plt.title('Histogram of SAT scores with different interval colors')
plt.show()

# %%
# prompt: create a histogram using seaborn and allot different color to each interval

# To allot different colors to each interval in a histogram using seaborn,
# you typically need to use matplotlib directly after generating the histogram
# or create the bins manually and then plot.
# Seaborn's `histplot` doesn't have a direct parameter to color individual bins
# differently based on their interval index.

# However, we can achieve this by first plotting with seaborn (or matplotlib)
# and then iterating through the patches (bars) and setting their colors.

plt.figure() # Create a new figure for the next plot

# Using seaborn to generate the histogram and get the bin information
# We don't need to plot directly with seaborn if we want to control colors per bar,
# but we can use it to understand the data distribution or get bins.

# Alternatively, let's stick to the matplotlib approach as shown previously,
# which provides easier access to individual bars.

n, bins, patches = plt.hist(df1['SAT'], bins=10)

# Assign different colors to intervals
colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown', 'pink', 'gray', 'olive', 'cyan']

for i in range(len(patches)):
  # Cycle through the defined colors
  patches[i].set_facecolor(colors[i % len(colors)])


plt.xlabel('SATSCORES')
plt.ylabel('FREQUENCY')
plt.title('Histogram of SAT scores with different interval colors (Seaborn style concept)')
plt.show()

# %%
plt.plot(df1['SAT'],df1['Accept'],'bo')

# %%
# prompt: make scatter plot of above

plt.figure() # Create a new figure for the next plot
plt.scatter(df1['SAT'], df1['Accept'])
plt.xlabel('SAT Scores')
plt.ylabel('Acceptance Rate')
plt.title('Scatter Plot of SAT Scores vs. Acceptance Rate')
plt.show()

# %%
# prompt: line plot

# Line plot example (using dummy data as there's no time-series or ordered data in df1)

# Create some dummy data for a line plot
# Let's assume 'SAT' scores change over some imaginary index or time
# This is just for demonstration purposes as df1 doesn't have a natural x-axis for a line plot
df1_sorted_by_SAT = df1.sort_values(by='SAT').reset_index(drop=True)

plt.figure(figsize=(10, 6))
plt.plot(df1_sorted_by_SAT.index, df1_sorted_by_SAT['SAT'], marker='o', linestyle='-')
plt.xlabel('Index (Sorted by SAT)')
plt.ylabel('SAT Score')
plt.title('SAT Score Trend (Sorted)')
plt.grid(True)
plt.show()

# Another line plot example using 'Accept'
plt.figure(figsize=(10, 6))
plt.plot(df1_sorted_by_SAT.index, df1_sorted_by_SAT['Accept'], marker='o', linestyle='-', color='red')
plt.xlabel('Index (Sorted by SAT)')
plt.ylabel('Acceptance Rate')
plt.title('Acceptance Rate Trend (Sorted by SAT)')
plt.grid(True)
plt.show()

# %%
plt.plot(df1['SAT'],df1['Top10'],'rs')

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1['Accept'],df1['Top10'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-55-3552059006.py in <cell line: 0>()
# ----> 1 sns.pairplot(df1['Accept'],df1['Top10'])
#
# TypeError: pairplot() takes 1 positional argument but 2 were given

# %%
plt.boxplot(df1['SAT'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ccc17b37d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ccc26bcb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ccc291b110>],
#  'medians': [<matplotlib.lines.Line2D at 0x78ccc25d5b90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78ccc25d72d0>],
#  'means': []}
